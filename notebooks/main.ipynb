# %%
# Parameters
n_mels = 512        # Number of freq divisions in mel spectrogram
encoddings = 100     # Different drum encodings
depth = 100

window_skip = 16     # Steps skipped in focus window 
window_size = 64  # or any other desired value

mp3_directory = '..\data\\raw\MP3'
gp5_directory = '..\data\\raw\GP5'

# %%
# Data load and processing
from song_manager import SongManager

manager = SongManager()
manager.load_dataset(mp3_directory, gp5_directory, n_mels=n_mels, skip=window_skip, window_size=window_size)
[X_i, Y_i] = manager.get_all_windows(window_size)

from sklearn.preprocessing import StandardScaler
# Create a scaler object
scaler = StandardScaler()

# Fit and transform the X data
X = scaler.fit_transform(X_i.reshape(-1, 1))
X = X.reshape(X_i.shape)

# %%
import sys
import numpy as np
X = X.astype(np.float16)
Y = Y_i.astype(np.float16)

size_in_bytes = sys.getsizeof(X)
print(f"Memory size of variable: {size_in_bytes} bytes")

size_in_bytes = sys.getsizeof(Y)
print(f"Memory size of variable: {size_in_bytes} bytes")
# Out:
# Memory size of variable: 193069200 bytes
# Memory size of variable: 37708944 bytes

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
print(tf.__version__)
print(tf.test.is_built_with_gpu_support())
tf.test.is_built_with_cuda()
tf.config.list_physical_devices('GPU')

#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
from tensorflow.keras import mixed_precision

policy_name = "mixed_float16"  # if you train on a GPU
policy = mixed_precision.Policy(policy_name)
mixed_precision.set_global_policy(policy)

print('Compute dtype: %s' % policy.compute_dtype)
print('Variable dtype: %s' % policy.variable_dtype)
# Out:
# Num GPUs Available:  1
# 2.10.0
# True
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   NVIDIA GeForce MX150, compute capability 6.1
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# Compute dtype: float16
# Variable dtype: float32

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Concatenate, Activation, TimeDistributed
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import he_normal, glorot_normal

model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(window_size, 512)))
model.add(Dropout(0.2))
model.add(LSTM(64, return_sequences=True))
model.add(Dropout(0.2))
model.add(Dense(64,kernel_initializer=he_normal())) # Use Dense(1) for regression
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(Dense(64,kernel_initializer=he_normal())) # Use Dense(1) for regression
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(TimeDistributed(Dense(depth, dtype='float32', activation='sigmoid')))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64, 128)           328192
#
#  dropout (Dropout)           (None, 64, 128)           0
#
#  lstm_1 (LSTM)               (None, 64, 64)            49408
#
#  dropout_1 (Dropout)         (None, 64, 64)            0
#
#  dense (Dense)               (None, 64, 64)            4160
#
#  activation (Activation)     (None, 64, 64)            0
#
#  dropout_2 (Dropout)         (None, 64, 64)            0
#
#  dense_1 (Dense)             (None, 64, 64)            4160
#
#  activation_1 (Activation)   (None, 64, 64)            0
#
#  dropout_3 (Dropout)         (None, 64, 64)            0
#
#  time_distributed (TimeDistr  (None, 64, 100)          6500
#  ibuted)
#
# =================================================================
# Total params: 392,420
# Trainable params: 392,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
from visualization import visualize
from tensorflow.keras.models import load_model

#model = load_model('Models\DNET_V1.h5')
history = model.fit(X, Y, epochs=250, batch_size=64, validation_split=0.3)
model.save('Models\DNET_V2.h5')  #creates a HDF5 file 'my_model.h5'
visualize.plot_training_history(history)
# Out:
# Epoch 1/250
# 33/33 [==============================] - 12s 86ms/step - loss: 0.3975 - accuracy: 0.0043 - val_loss: 0.0202 - val_accuracy: 0.0000e+00
# Epoch 2/250
# 33/33 [==============================] - 2s 52ms/step - loss: 0.0136 - accuracy: 0.0022 - val_loss: 0.0042 - val_accuracy: 0.0127
# Epoch 3/250
# 33/33 [==============================] - 2s 54ms/step - loss: 0.0048 - accuracy: 0.0069 - val_loss: 0.0039 - val_accuracy: 0.0127
# Epoch 4/250
# 33/33 [==============================] - 2s 51ms/step - loss: 0.0044 - accuracy: 0.0085 - val_loss: 0.0037 - val_accuracy: 0.0127
# Epoch 5/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0041 - accuracy: 0.0100 - val_loss: 0.0036 - val_accuracy: 0.0127
# Epoch 6/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0038 - accuracy: 0.0108 - val_loss: 0.0034 - val_accuracy: 0.0127
# Epoch 7/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0037 - accuracy: 0.0111 - val_loss: 0.0034 - val_accuracy: 0.0127
# Epoch 8/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0035 - accuracy: 0.0119 - val_loss: 0.0033 - val_accuracy: 0.0127
# Epoch 9/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0034 - accuracy: 0.0127 - val_loss: 0.0032 - val_accuracy: 0.0127
# Epoch 10/250
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0032 - accuracy: 0.0126 - val_loss: 0.0031 - val_accuracy: 0.0127
# Epoch 11/250
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0032 - accuracy: 0.0134 - val_loss: 0.0031 - val_accuracy: 0.0127
# Epoch 12/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0031 - accuracy: 0.0136 - val_loss: 0.0030 - val_accuracy: 0.0127
# Epoch 13/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0030 - accuracy: 0.0143 - val_loss: 0.0030 - val_accuracy: 0.0127
# Epoch 14/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0030 - accuracy: 0.0147 - val_loss: 0.0029 - val_accuracy: 0.0127
# Epoch 15/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0029 - accuracy: 0.0147 - val_loss: 0.0029 - val_accuracy: 0.0127
# Epoch 16/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0029 - accuracy: 0.0151 - val_loss: 0.0029 - val_accuracy: 0.0127
# Epoch 17/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0028 - accuracy: 0.0152 - val_loss: 0.0028 - val_accuracy: 0.0127
# Epoch 18/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0028 - accuracy: 0.0154 - val_loss: 0.0028 - val_accuracy: 0.0127
# Epoch 19/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0028 - accuracy: 0.0156 - val_loss: 0.0027 - val_accuracy: 0.0127
# Epoch 20/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0027 - accuracy: 0.0159 - val_loss: 0.0027 - val_accuracy: 0.0127
# Epoch 21/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0027 - accuracy: 0.0160 - val_loss: 0.0026 - val_accuracy: 0.0127
# Epoch 22/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0026 - accuracy: 0.0161 - val_loss: 0.0026 - val_accuracy: 0.0127
# Epoch 23/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0026 - accuracy: 0.0165 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 24/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0025 - accuracy: 0.0164 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 25/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0025 - accuracy: 0.0170 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 26/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0025 - accuracy: 0.0170 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 27/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0024 - accuracy: 0.0170 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 28/250
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0024 - accuracy: 0.0171 - val_loss: 0.0024 - val_accuracy: 0.0127
# Epoch 29/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0023 - accuracy: 0.0174 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 30/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0023 - accuracy: 0.0175 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 31/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0022 - accuracy: 0.0175 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 32/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0021 - accuracy: 0.0177 - val_loss: 0.0025 - val_accuracy: 0.0127
# Epoch 33/250
# 33/33 [==============================] - 2s 47ms/step - loss: 0.0021 - accuracy: 0.0183 - val_loss: 0.0026 - val_accuracy: 0.0125
# Epoch 34/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0021 - accuracy: 0.0180 - val_loss: 0.0025 - val_accuracy: 0.0122
# Epoch 35/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0020 - accuracy: 0.0184 - val_loss: 0.0026 - val_accuracy: 0.0124
# Epoch 36/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0020 - accuracy: 0.0184 - val_loss: 0.0025 - val_accuracy: 0.0125
# Epoch 37/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0020 - accuracy: 0.0184 - val_loss: 0.0025 - val_accuracy: 0.0124
# Epoch 38/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0019 - accuracy: 0.0185 - val_loss: 0.0025 - val_accuracy: 0.0124
# Epoch 39/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0019 - accuracy: 0.0185 - val_loss: 0.0025 - val_accuracy: 0.0122
# Epoch 40/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0018 - accuracy: 0.0185 - val_loss: 0.0024 - val_accuracy: 0.0120
# Epoch 41/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0018 - accuracy: 0.0188 - val_loss: 0.0025 - val_accuracy: 0.0122
# Epoch 42/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0018 - accuracy: 0.0187 - val_loss: 0.0024 - val_accuracy: 0.0122
# Epoch 43/250
# 33/33 [==============================] - 2s 51ms/step - loss: 0.0017 - accuracy: 0.0188 - val_loss: 0.0024 - val_accuracy: 0.0122
# Epoch 44/250
# 33/33 [==============================] - 2s 55ms/step - loss: 0.0017 - accuracy: 0.0186 - val_loss: 0.0025 - val_accuracy: 0.0118
# Epoch 45/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0017 - accuracy: 0.0185 - val_loss: 0.0025 - val_accuracy: 0.0121
# Epoch 46/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0016 - accuracy: 0.0187 - val_loss: 0.0025 - val_accuracy: 0.0117
# Epoch 47/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0016 - accuracy: 0.0185 - val_loss: 0.0026 - val_accuracy: 0.0101
# Epoch 48/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0016 - accuracy: 0.0183 - val_loss: 0.0025 - val_accuracy: 0.0121
# Epoch 49/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0015 - accuracy: 0.0183 - val_loss: 0.0025 - val_accuracy: 0.0122
# Epoch 50/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0015 - accuracy: 0.0186 - val_loss: 0.0024 - val_accuracy: 0.0119
# Epoch 51/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0015 - accuracy: 0.0184 - val_loss: 0.0025 - val_accuracy: 0.0120
# Epoch 52/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0014 - accuracy: 0.0185 - val_loss: 0.0025 - val_accuracy: 0.0098
# Epoch 53/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0014 - accuracy: 0.0185 - val_loss: 0.0025 - val_accuracy: 0.0086
# Epoch 54/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0014 - accuracy: 0.0185 - val_loss: 0.0024 - val_accuracy: 0.0080
# Epoch 55/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0014 - accuracy: 0.0184 - val_loss: 0.0025 - val_accuracy: 0.0084
# Epoch 56/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0014 - accuracy: 0.0190 - val_loss: 0.0025 - val_accuracy: 0.0077
# Epoch 57/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0014 - accuracy: 0.0187 - val_loss: 0.0027 - val_accuracy: 0.0078
# Epoch 58/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0014 - accuracy: 0.0188 - val_loss: 0.0025 - val_accuracy: 0.0066
# Epoch 59/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0013 - accuracy: 0.0190 - val_loss: 0.0025 - val_accuracy: 0.0064
# Epoch 60/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0013 - accuracy: 0.0186 - val_loss: 0.0026 - val_accuracy: 0.0091
# Epoch 61/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0013 - accuracy: 0.0191 - val_loss: 0.0026 - val_accuracy: 0.0076
# Epoch 62/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0013 - accuracy: 0.0193 - val_loss: 0.0026 - val_accuracy: 0.0066
# Epoch 63/250
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0013 - accuracy: 0.0191 - val_loss: 0.0026 - val_accuracy: 0.0069
# Epoch 64/250
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0013 - accuracy: 0.0193 - val_loss: 0.0026 - val_accuracy: 0.0066
# Epoch 65/250
# 33/33 [==============================] - 2s 50ms/step - loss: 0.0013 - accuracy: 0.0196 - val_loss: 0.0028 - val_accuracy: 0.0066
# Epoch 66/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0012 - accuracy: 0.0196 - val_loss: 0.0027 - val_accuracy: 0.0068
# Epoch 67/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0012 - accuracy: 0.0195 - val_loss: 0.0028 - val_accuracy: 0.0068
# Epoch 68/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0012 - accuracy: 0.0194 - val_loss: 0.0027 - val_accuracy: 0.0062
# Epoch 69/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0012 - accuracy: 0.0197 - val_loss: 0.0029 - val_accuracy: 0.0065
# Epoch 70/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0012 - accuracy: 0.0199 - val_loss: 0.0029 - val_accuracy: 0.0063
# Epoch 71/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0012 - accuracy: 0.0200 - val_loss: 0.0027 - val_accuracy: 0.0074
# Epoch 72/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0011 - accuracy: 0.0200 - val_loss: 0.0031 - val_accuracy: 0.0060
# Epoch 73/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0011 - accuracy: 0.0202 - val_loss: 0.0028 - val_accuracy: 0.0057
# Epoch 74/250
# 33/33 [==============================] - 2s 49ms/step - loss: 0.0011 - accuracy: 0.0203 - val_loss: 0.0028 - val_accuracy: 0.0061
# Epoch 75/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0011 - accuracy: 0.0204 - val_loss: 0.0030 - val_accuracy: 0.0066
# Epoch 76/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0011 - accuracy: 0.0206 - val_loss: 0.0035 - val_accuracy: 0.0070
# Epoch 77/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0011 - accuracy: 0.0206 - val_loss: 0.0031 - val_accuracy: 0.0065
# Epoch 78/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0010 - accuracy: 0.0208 - val_loss: 0.0032 - val_accuracy: 0.0063
# Epoch 79/250
# 33/33 [==============================] - 2s 48ms/step - loss: 0.0010 - accuracy: 0.0212 - val_loss: 0.0031 - val_accuracy: 0.0072
# Epoch 80/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.9931e-04 - accuracy: 0.0213 - val_loss: 0.0032 - val_accuracy: 0.0055
# Epoch 81/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.7335e-04 - accuracy: 0.0215 - val_loss: 0.0031 - val_accuracy: 0.0056
# Epoch 82/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.7397e-04 - accuracy: 0.0214 - val_loss: 0.0032 - val_accuracy: 0.0061
# Epoch 83/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.6466e-04 - accuracy: 0.0212 - val_loss: 0.0036 - val_accuracy: 0.0061
# Epoch 84/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.3992e-04 - accuracy: 0.0216 - val_loss: 0.0034 - val_accuracy: 0.0067
# Epoch 85/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.5802e-04 - accuracy: 0.0212 - val_loss: 0.0031 - val_accuracy: 0.0060
# Epoch 86/250
# 33/33 [==============================] - 2s 49ms/step - loss: 9.3664e-04 - accuracy: 0.0216 - val_loss: 0.0033 - val_accuracy: 0.0062
# Epoch 87/250
# 33/33 [==============================] - 2s 49ms/step - loss: 8.8970e-04 - accuracy: 0.0214 - val_loss: 0.0037 - val_accuracy: 0.0065
# Epoch 88/250
# 33/33 [==============================] - 2s 49ms/step - loss: 8.7755e-04 - accuracy: 0.0215 - val_loss: 0.0036 - val_accuracy: 0.0062
# Epoch 89/250
# 33/33 [==============================] - 2s 48ms/step - loss: 8.4420e-04 - accuracy: 0.0218 - val_loss: 0.0040 - val_accuracy: 0.0068
# Epoch 90/250
# 33/33 [==============================] - 2s 48ms/step - loss: 8.5398e-04 - accuracy: 0.0217 - val_loss: 0.0038 - val_accuracy: 0.0072
# Epoch 91/250
# 33/33 [==============================] - 2s 50ms/step - loss: 8.2734e-04 - accuracy: 0.0217 - val_loss: 0.0040 - val_accuracy: 0.0070
# Epoch 92/250
# 33/33 [==============================] - 2s 48ms/step - loss: 8.1006e-04 - accuracy: 0.0218 - val_loss: 0.0040 - val_accuracy: 0.0061
# Epoch 93/250
# 33/33 [==============================] - 2s 48ms/step - loss: 8.1179e-04 - accuracy: 0.0214 - val_loss: 0.0041 - val_accuracy: 0.0063
# Epoch 94/250
# 33/33 [==============================] - 2s 49ms/step - loss: 7.8214e-04 - accuracy: 0.0218 - val_loss: 0.0041 - val_accuracy: 0.0073
# Epoch 95/250
# 33/33 [==============================] - 2s 48ms/step - loss: 7.6875e-04 - accuracy: 0.0218 - val_loss: 0.0042 - val_accuracy: 0.0065
# Epoch 96/250
# 33/33 [==============================] - 2s 48ms/step - loss: 7.9836e-04 - accuracy: 0.0217 - val_loss: 0.0044 - val_accuracy: 0.0072
# Epoch 97/250
# 33/33 [==============================] - 2s 49ms/step - loss: 7.7700e-04 - accuracy: 0.0215 - val_loss: 0.0042 - val_accuracy: 0.0063
# Epoch 98/250
# 33/33 [==============================] - 2s 49ms/step - loss: 7.3522e-04 - accuracy: 0.0218 - val_loss: 0.0042 - val_accuracy: 0.0067
# Epoch 99/250
# 33/33 [==============================] - 2s 48ms/step - loss: 7.1933e-04 - accuracy: 0.0220 - val_loss: 0.0045 - val_accuracy: 0.0067
# Epoch 100/250
# 33/33 [==============================] - 2s 48ms/step - loss: 6.9214e-04 - accuracy: 0.0220 - val_loss: 0.0044 - val_accuracy: 0.0068
# Epoch 101/250
# 33/33 [==============================] - 2s 48ms/step - loss: 6.9232e-04 - accuracy: 0.0218 - val_loss: 0.0042 - val_accuracy: 0.0069
# Epoch 102/250
# 33/33 [==============================] - 2s 49ms/step - loss: 6.8100e-04 - accuracy: 0.0219 - val_loss: 0.0045 - val_accuracy: 0.0069
# Epoch 103/250
# 33/33 [==============================] - 2s 48ms/step - loss: 6.6740e-04 - accuracy: 0.0218 - val_loss: 0.0047 - val_accuracy: 0.0069
# Epoch 104/250
# 33/33 [==============================] - 2s 52ms/step - loss: 6.6722e-04 - accuracy: 0.0217 - val_loss: 0.0047 - val_accuracy: 0.0069
# Epoch 105/250
# 33/33 [==============================] - 2s 49ms/step - loss: 6.5923e-04 - accuracy: 0.0214 - val_loss: 0.0046 - val_accuracy: 0.0068
# Epoch 106/250
# 33/33 [==============================] - 2s 49ms/step - loss: 6.4082e-04 - accuracy: 0.0220 - val_loss: 0.0049 - val_accuracy: 0.0072
# Epoch 107/250
# 33/33 [==============================] - 2s 49ms/step - loss: 6.1620e-04 - accuracy: 0.0216 - val_loss: 0.0050 - val_accuracy: 0.0060
# Epoch 108/250
# 33/33 [==============================] - 2s 48ms/step - loss: 6.0025e-04 - accuracy: 0.0218 - val_loss: 0.0052 - val_accuracy: 0.0069
# Epoch 109/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.8128e-04 - accuracy: 0.0218 - val_loss: 0.0053 - val_accuracy: 0.0045
# Epoch 110/250
# 33/33 [==============================] - 2s 49ms/step - loss: 5.8660e-04 - accuracy: 0.0219 - val_loss: 0.0053 - val_accuracy: 0.0076
# Epoch 111/250
# 33/33 [==============================] - 2s 49ms/step - loss: 5.8137e-04 - accuracy: 0.0220 - val_loss: 0.0049 - val_accuracy: 0.0045
# Epoch 112/250
# 33/33 [==============================] - 2s 48ms/step - loss: 6.0679e-04 - accuracy: 0.0213 - val_loss: 0.0053 - val_accuracy: 0.0027
# Epoch 113/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.8793e-04 - accuracy: 0.0217 - val_loss: 0.0053 - val_accuracy: 0.0066
# Epoch 114/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.5442e-04 - accuracy: 0.0215 - val_loss: 0.0051 - val_accuracy: 0.0035
# Epoch 115/250
# 33/33 [==============================] - 2s 49ms/step - loss: 5.4883e-04 - accuracy: 0.0217 - val_loss: 0.0052 - val_accuracy: 0.0050
# Epoch 116/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.8045e-04 - accuracy: 0.0217 - val_loss: 0.0051 - val_accuracy: 0.0046
# Epoch 117/250
# 33/33 [==============================] - 2s 49ms/step - loss: 5.2860e-04 - accuracy: 0.0216 - val_loss: 0.0055 - val_accuracy: 0.0025
# Epoch 118/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.4722e-04 - accuracy: 0.0217 - val_loss: 0.0052 - val_accuracy: 0.0014
# Epoch 119/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.2651e-04 - accuracy: 0.0216 - val_loss: 0.0054 - val_accuracy: 0.0026
# Epoch 120/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.0949e-04 - accuracy: 0.0218 - val_loss: 0.0054 - val_accuracy: 0.0056
# Epoch 121/250
# 33/33 [==============================] - 2s 49ms/step - loss: 5.0057e-04 - accuracy: 0.0219 - val_loss: 0.0057 - val_accuracy: 0.0019
# Epoch 122/250
# 33/33 [==============================] - 2s 49ms/step - loss: 4.8315e-04 - accuracy: 0.0216 - val_loss: 0.0056 - val_accuracy: 0.0025
# Epoch 123/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.0248e-04 - accuracy: 0.0219 - val_loss: 0.0054 - val_accuracy: 0.0027
# Epoch 124/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.7236e-04 - accuracy: 0.0219 - val_loss: 0.0054 - val_accuracy: 0.0031
# Epoch 125/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.9529e-04 - accuracy: 0.0216 - val_loss: 0.0055 - val_accuracy: 0.0033
# Epoch 126/250
# 33/33 [==============================] - 2s 48ms/step - loss: 5.1888e-04 - accuracy: 0.0217 - val_loss: 0.0055 - val_accuracy: 0.0030
# Epoch 127/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.6439e-04 - accuracy: 0.0219 - val_loss: 0.0055 - val_accuracy: 0.0019
# Epoch 128/250
# 33/33 [==============================] - 2s 49ms/step - loss: 4.5724e-04 - accuracy: 0.0222 - val_loss: 0.0056 - val_accuracy: 0.0013
# Epoch 129/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.5787e-04 - accuracy: 0.0219 - val_loss: 0.0054 - val_accuracy: 0.0026
# Epoch 130/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.4494e-04 - accuracy: 0.0216 - val_loss: 0.0057 - val_accuracy: 0.0014
# Epoch 131/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.2313e-04 - accuracy: 0.0226 - val_loss: 0.0058 - val_accuracy: 0.0019
# Epoch 132/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.2516e-04 - accuracy: 0.0219 - val_loss: 0.0058 - val_accuracy: 0.0018
# Epoch 133/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.1841e-04 - accuracy: 0.0223 - val_loss: 0.0060 - val_accuracy: 0.0011
# Epoch 134/250
# 33/33 [==============================] - 2s 48ms/step - loss: 4.1074e-04 - accuracy: 0.0220 - val_loss: 0.0060 - val_accuracy: 0.0011
# Epoch 135/250
# 33/33 [==============================] - 2s 49ms/step - loss: 4.0558e-04 - accuracy: 0.0221 - val_loss: 0.0059 - val_accuracy: 9.1912e-04
# Epoch 136/250
# 33/33 [==============================] - 2s 49ms/step - loss: 4.1105e-04 - accuracy: 0.0224 - val_loss: 0.0058 - val_accuracy: 0.0013
# Epoch 137/250
# 33/33 [==============================] - 2s 49ms/step - loss: 4.0475e-04 - accuracy: 0.0222 - val_loss: 0.0060 - val_accuracy: 0.0011
# Epoch 138/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.8575e-04 - accuracy: 0.0224 - val_loss: 0.0060 - val_accuracy: 0.0011
# Epoch 139/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.8689e-04 - accuracy: 0.0222 - val_loss: 0.0061 - val_accuracy: 7.7771e-04
# Epoch 140/250
# 33/33 [==============================] - 2s 49ms/step - loss: 4.0616e-04 - accuracy: 0.0221 - val_loss: 0.0061 - val_accuracy: 0.0013
# Epoch 141/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.9670e-04 - accuracy: 0.0221 - val_loss: 0.0060 - val_accuracy: 0.0011
# Epoch 142/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.7271e-04 - accuracy: 0.0223 - val_loss: 0.0061 - val_accuracy: 9.1912e-04
# Epoch 143/250
# 33/33 [==============================] - 2s 48ms/step - loss: 3.7577e-04 - accuracy: 0.0224 - val_loss: 0.0060 - val_accuracy: 0.0011
# Epoch 144/250
# 33/33 [==============================] - 2s 48ms/step - loss: 3.8355e-04 - accuracy: 0.0223 - val_loss: 0.0059 - val_accuracy: 9.7214e-04
# Epoch 145/250
# 33/33 [==============================] - 2s 48ms/step - loss: 3.7241e-04 - accuracy: 0.0226 - val_loss: 0.0060 - val_accuracy: 9.1912e-04
# Epoch 146/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.9086e-04 - accuracy: 0.0228 - val_loss: 0.0062 - val_accuracy: 8.6609e-04
# Epoch 147/250
# 33/33 [==============================] - 2s 48ms/step - loss: 3.5420e-04 - accuracy: 0.0225 - val_loss: 0.0061 - val_accuracy: 0.0015
# Epoch 148/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.4408e-04 - accuracy: 0.0227 - val_loss: 0.0061 - val_accuracy: 9.7214e-04
# Epoch 149/250
# 33/33 [==============================] - 2s 55ms/step - loss: 3.3756e-04 - accuracy: 0.0227 - val_loss: 0.0061 - val_accuracy: 8.1307e-04
# Epoch 150/250
# 33/33 [==============================] - 2s 59ms/step - loss: 3.4744e-04 - accuracy: 0.0230 - val_loss: 0.0064 - val_accuracy: 7.0701e-04
# Epoch 151/250
# 33/33 [==============================] - 2s 57ms/step - loss: 3.5291e-04 - accuracy: 0.0229 - val_loss: 0.0061 - val_accuracy: 0.0013
# Epoch 152/250
# 33/33 [==============================] - 2s 58ms/step - loss: 3.3755e-04 - accuracy: 0.0229 - val_loss: 0.0061 - val_accuracy: 0.0013
# Epoch 153/250
# 33/33 [==============================] - 2s 61ms/step - loss: 3.9260e-04 - accuracy: 0.0231 - val_loss: 0.0062 - val_accuracy: 9.0144e-04
# Epoch 154/250
# 33/33 [==============================] - 2s 52ms/step - loss: 3.8874e-04 - accuracy: 0.0228 - val_loss: 0.0060 - val_accuracy: 0.0013
# Epoch 155/250
# 33/33 [==============================] - 2s 50ms/step - loss: 3.4091e-04 - accuracy: 0.0233 - val_loss: 0.0060 - val_accuracy: 0.0013
# Epoch 156/250
# 33/33 [==============================] - 2s 54ms/step - loss: 3.2433e-04 - accuracy: 0.0234 - val_loss: 0.0062 - val_accuracy: 8.4842e-04
# Epoch 157/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.1579e-04 - accuracy: 0.0230 - val_loss: 0.0062 - val_accuracy: 8.3074e-04
# Epoch 158/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.2149e-04 - accuracy: 0.0231 - val_loss: 0.0062 - val_accuracy: 8.4842e-04
# Epoch 159/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.9914e-04 - accuracy: 0.0235 - val_loss: 0.0063 - val_accuracy: 0.0011
# Epoch 160/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.9155e-04 - accuracy: 0.0236 - val_loss: 0.0063 - val_accuracy: 5.4794e-04
# Epoch 161/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.9506e-04 - accuracy: 0.0237 - val_loss: 0.0063 - val_accuracy: 9.5447e-04
# Epoch 162/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.8147e-04 - accuracy: 0.0236 - val_loss: 0.0064 - val_accuracy: 4.5956e-04
# Epoch 163/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.8536e-04 - accuracy: 0.0236 - val_loss: 0.0064 - val_accuracy: 6.7166e-04
# Epoch 164/250
# 33/33 [==============================] - 2s 48ms/step - loss: 3.0460e-04 - accuracy: 0.0234 - val_loss: 0.0063 - val_accuracy: 0.0011
# Epoch 165/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.9417e-04 - accuracy: 0.0238 - val_loss: 0.0064 - val_accuracy: 8.6609e-04
# Epoch 166/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.7964e-04 - accuracy: 0.0239 - val_loss: 0.0063 - val_accuracy: 7.4236e-04
# Epoch 167/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.7666e-04 - accuracy: 0.0241 - val_loss: 0.0064 - val_accuracy: 9.8982e-04
# Epoch 168/250
# 33/33 [==============================] - 2s 49ms/step - loss: 3.0189e-04 - accuracy: 0.0238 - val_loss: 0.0063 - val_accuracy: 0.0016
# Epoch 169/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.8519e-04 - accuracy: 0.0238 - val_loss: 0.0064 - val_accuracy: 7.0701e-04
# Epoch 170/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.6202e-04 - accuracy: 0.0242 - val_loss: 0.0064 - val_accuracy: 0.0011
# Epoch 171/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.4488e-04 - accuracy: 0.0245 - val_loss: 0.0064 - val_accuracy: 8.1307e-04
# Epoch 172/250
# 33/33 [==============================] - 2s 50ms/step - loss: 2.3524e-04 - accuracy: 0.0246 - val_loss: 0.0065 - val_accuracy: 9.1912e-04
# Epoch 173/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.3464e-04 - accuracy: 0.0244 - val_loss: 0.0065 - val_accuracy: 9.5447e-04
# Epoch 174/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.5235e-04 - accuracy: 0.0242 - val_loss: 0.0064 - val_accuracy: 7.2469e-04
# Epoch 175/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.3244e-04 - accuracy: 0.0244 - val_loss: 0.0065 - val_accuracy: 0.0017
# Epoch 176/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.3194e-04 - accuracy: 0.0244 - val_loss: 0.0065 - val_accuracy: 9.3679e-04
# Epoch 177/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.2538e-04 - accuracy: 0.0246 - val_loss: 0.0065 - val_accuracy: 0.0010
# Epoch 178/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.3133e-04 - accuracy: 0.0241 - val_loss: 0.0065 - val_accuracy: 6.7166e-04
# Epoch 179/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.2205e-04 - accuracy: 0.0248 - val_loss: 0.0066 - val_accuracy: 8.3074e-04
# Epoch 180/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.3316e-04 - accuracy: 0.0245 - val_loss: 0.0066 - val_accuracy: 0.0022
# Epoch 181/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.2556e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 7.0701e-04
# Epoch 182/250
# 33/33 [==============================] - 2s 48ms/step - loss: 2.2433e-04 - accuracy: 0.0246 - val_loss: 0.0066 - val_accuracy: 0.0021
# Epoch 183/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.4906e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0015
# Epoch 184/250
# 33/33 [==============================] - 2s 49ms/step - loss: 2.2818e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0028
# Epoch 185/250
# 33/33 [==============================] - 2s 51ms/step - loss: 2.1259e-04 - accuracy: 0.0246 - val_loss: 0.0066 - val_accuracy: 0.0012
# Epoch 186/250
# 33/33 [==============================] - 2s 50ms/step - loss: 2.0265e-04 - accuracy: 0.0246 - val_loss: 0.0066 - val_accuracy: 0.0016
# Epoch 187/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.9118e-04 - accuracy: 0.0245 - val_loss: 0.0066 - val_accuracy: 0.0018
# Epoch 188/250
# 33/33 [==============================] - 2s 51ms/step - loss: 2.2822e-04 - accuracy: 0.0243 - val_loss: 0.0065 - val_accuracy: 0.0031
# Epoch 189/250
# 33/33 [==============================] - 2s 58ms/step - loss: 2.3656e-04 - accuracy: 0.0241 - val_loss: 0.0066 - val_accuracy: 0.0061
# Epoch 190/250
# 33/33 [==============================] - 2s 54ms/step - loss: 2.3266e-04 - accuracy: 0.0241 - val_loss: 0.0066 - val_accuracy: 0.0021
# Epoch 191/250
# 33/33 [==============================] - 2s 54ms/step - loss: 1.9843e-04 - accuracy: 0.0243 - val_loss: 0.0066 - val_accuracy: 0.0023
# Epoch 192/250
# 33/33 [==============================] - 2s 58ms/step - loss: 1.8439e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 9.5447e-04
# Epoch 193/250
# 33/33 [==============================] - 2s 56ms/step - loss: 1.8758e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0015
# Epoch 194/250
# 33/33 [==============================] - 2s 51ms/step - loss: 1.9725e-04 - accuracy: 0.0245 - val_loss: 0.0066 - val_accuracy: 0.0025
# Epoch 195/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.6968e-04 - accuracy: 0.0247 - val_loss: 0.0066 - val_accuracy: 0.0022
# Epoch 196/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.6627e-04 - accuracy: 0.0245 - val_loss: 0.0066 - val_accuracy: 0.0012
# Epoch 197/250
# 33/33 [==============================] - 2s 53ms/step - loss: 1.6359e-04 - accuracy: 0.0242 - val_loss: 0.0066 - val_accuracy: 0.0016
# Epoch 198/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.6173e-04 - accuracy: 0.0247 - val_loss: 0.0069 - val_accuracy: 9.0144e-04
# Epoch 199/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.6688e-04 - accuracy: 0.0246 - val_loss: 0.0068 - val_accuracy: 0.0021
# Epoch 200/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.5604e-04 - accuracy: 0.0243 - val_loss: 0.0067 - val_accuracy: 0.0033
# Epoch 201/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.8023e-04 - accuracy: 0.0246 - val_loss: 0.0067 - val_accuracy: 0.0029
# Epoch 202/250
# 33/33 [==============================] - 2s 50ms/step - loss: 2.2501e-04 - accuracy: 0.0242 - val_loss: 0.0065 - val_accuracy: 0.0048
# Epoch 203/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.8635e-04 - accuracy: 0.0243 - val_loss: 0.0066 - val_accuracy: 0.0044
# Epoch 204/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.6260e-04 - accuracy: 0.0247 - val_loss: 0.0065 - val_accuracy: 0.0022
# Epoch 205/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.4632e-04 - accuracy: 0.0248 - val_loss: 0.0066 - val_accuracy: 0.0036
# Epoch 206/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.6665e-04 - accuracy: 0.0244 - val_loss: 0.0065 - val_accuracy: 0.0029
# Epoch 207/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.5693e-04 - accuracy: 0.0247 - val_loss: 0.0066 - val_accuracy: 0.0024
# Epoch 208/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.5507e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0051
# Epoch 209/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.4836e-04 - accuracy: 0.0244 - val_loss: 0.0065 - val_accuracy: 0.0032
# Epoch 210/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.4326e-04 - accuracy: 0.0246 - val_loss: 0.0067 - val_accuracy: 0.0030
# Epoch 211/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.3063e-04 - accuracy: 0.0248 - val_loss: 0.0067 - val_accuracy: 0.0025
# Epoch 212/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.4173e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0048
# Epoch 213/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.2308e-04 - accuracy: 0.0247 - val_loss: 0.0067 - val_accuracy: 0.0016
# Epoch 214/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.3325e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0023
# Epoch 215/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.3292e-04 - accuracy: 0.0246 - val_loss: 0.0069 - val_accuracy: 0.0042
# Epoch 216/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.5103e-04 - accuracy: 0.0241 - val_loss: 0.0067 - val_accuracy: 0.0032
# Epoch 217/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.3819e-04 - accuracy: 0.0242 - val_loss: 0.0066 - val_accuracy: 0.0032
# Epoch 218/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.2060e-04 - accuracy: 0.0249 - val_loss: 0.0067 - val_accuracy: 0.0049
# Epoch 219/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.1001e-04 - accuracy: 0.0248 - val_loss: 0.0068 - val_accuracy: 0.0037
# Epoch 220/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1219e-04 - accuracy: 0.0245 - val_loss: 0.0067 - val_accuracy: 0.0025
# Epoch 221/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.0731e-04 - accuracy: 0.0245 - val_loss: 0.0068 - val_accuracy: 0.0046
# Epoch 222/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.0848e-04 - accuracy: 0.0246 - val_loss: 0.0068 - val_accuracy: 0.0045
# Epoch 223/250
# 33/33 [==============================] - 2s 51ms/step - loss: 1.2598e-04 - accuracy: 0.0246 - val_loss: 0.0067 - val_accuracy: 0.0044
# Epoch 224/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1202e-04 - accuracy: 0.0245 - val_loss: 0.0068 - val_accuracy: 0.0039
# Epoch 225/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1397e-04 - accuracy: 0.0246 - val_loss: 0.0068 - val_accuracy: 0.0046
# Epoch 226/250
# 33/33 [==============================] - 2s 51ms/step - loss: 1.2612e-04 - accuracy: 0.0247 - val_loss: 0.0068 - val_accuracy: 0.0051
# Epoch 227/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.4356e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0047
# Epoch 228/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.2358e-04 - accuracy: 0.0244 - val_loss: 0.0066 - val_accuracy: 0.0066
# Epoch 229/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1870e-04 - accuracy: 0.0244 - val_loss: 0.0067 - val_accuracy: 0.0048
# Epoch 230/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.1711e-04 - accuracy: 0.0244 - val_loss: 0.0067 - val_accuracy: 0.0056
# Epoch 231/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1001e-04 - accuracy: 0.0243 - val_loss: 0.0067 - val_accuracy: 0.0052
# Epoch 232/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.0136e-04 - accuracy: 0.0241 - val_loss: 0.0066 - val_accuracy: 0.0048
# Epoch 233/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.1155e-04 - accuracy: 0.0248 - val_loss: 0.0068 - val_accuracy: 0.0054
# Epoch 234/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.0107e-04 - accuracy: 0.0249 - val_loss: 0.0069 - val_accuracy: 0.0056
# Epoch 235/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.0024e-04 - accuracy: 0.0247 - val_loss: 0.0067 - val_accuracy: 0.0034
# Epoch 236/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.2342e-04 - accuracy: 0.0244 - val_loss: 0.0069 - val_accuracy: 0.0072
# Epoch 237/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1506e-04 - accuracy: 0.0246 - val_loss: 0.0069 - val_accuracy: 0.0069
# Epoch 238/250
# 33/33 [==============================] - 2s 57ms/step - loss: 9.2405e-05 - accuracy: 0.0247 - val_loss: 0.0068 - val_accuracy: 0.0059
# Epoch 239/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.1729e-04 - accuracy: 0.0242 - val_loss: 0.0067 - val_accuracy: 0.0065
# Epoch 240/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.1637e-04 - accuracy: 0.0244 - val_loss: 0.0068 - val_accuracy: 0.0069
# Epoch 241/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.0504e-04 - accuracy: 0.0242 - val_loss: 0.0068 - val_accuracy: 0.0062
# Epoch 242/250
# 33/33 [==============================] - 2s 48ms/step - loss: 1.0326e-04 - accuracy: 0.0246 - val_loss: 0.0067 - val_accuracy: 0.0080
# Epoch 243/250
# 33/33 [==============================] - 2s 49ms/step - loss: 8.8846e-05 - accuracy: 0.0247 - val_loss: 0.0068 - val_accuracy: 0.0077
# Epoch 244/250
# 33/33 [==============================] - 2s 49ms/step - loss: 9.6320e-05 - accuracy: 0.0243 - val_loss: 0.0068 - val_accuracy: 0.0059
# Epoch 245/250
# 33/33 [==============================] - 2s 49ms/step - loss: 1.0095e-04 - accuracy: 0.0245 - val_loss: 0.0067 - val_accuracy: 0.0076
# Epoch 246/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.4191e-05 - accuracy: 0.0247 - val_loss: 0.0067 - val_accuracy: 0.0073
# Epoch 247/250
# 33/33 [==============================] - 2s 50ms/step - loss: 1.2577e-04 - accuracy: 0.0241 - val_loss: 0.0067 - val_accuracy: 0.0079
# Epoch 248/250
# 33/33 [==============================] - 2s 49ms/step - loss: 9.1263e-05 - accuracy: 0.0249 - val_loss: 0.0069 - val_accuracy: 0.0079
# Epoch 249/250
# 33/33 [==============================] - 2s 49ms/step - loss: 9.5489e-05 - accuracy: 0.0244 - val_loss: 0.0068 - val_accuracy: 0.0080
# Epoch 250/250
# 33/33 [==============================] - 2s 48ms/step - loss: 9.7435e-05 - accuracy: 0.0248 - val_loss: 0.0068 - val_accuracy: 0.0082

# %%
import matplotlib.pyplot as plt

def plot_training_history_logscale(history):
    plt.figure(figsize=(12, 4))
    
    # Plotting Loss
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss (log scale)')
    plt.yscale('log')  # Set y-axis to logarithmic scale
    plt.legend()

    # Plotting Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()
plot_training_history_logscale(history)

# %%
# Generate predictions for all examples in the validation dataset
thresholded_predictions = visualize.generate_thresholded_predictions(model, X, 0.5)
from sklearn.metrics import accuracy_score
true_acuracy = accuracy_score(Y.flatten(),thresholded_predictions.flatten())
print(true_acuracy)
# Out:
# 93/93 [==============================] - 2s 15ms/step
# 0.9998250806177869

# %%
from scipy import stats
import numpy as np
from scipy import stats

from scipy.stats import mode

def merge_windows(predictions, window_size, hop_size):
    """
    Merge overlapping windows of predictions into a single sequence using mode.
    
    Parameters:
    - predictions: 3D numpy array of shape (number of windows, window size, number of parameters).
    - window_size: The size of each window.
    - hop_size: The step size to move the window.
    
    Returns:
    - A single sequence of predictions.
    """

    num_windows, win_size, num_params = predictions.shape
    assert win_size == window_size, "Provided window size does not match the predictions shape."

    # Initialize a list to hold all predictions for each time step
    merged_predictions_list = [[[] for _ in range(num_params)] for _ in range((num_windows-1) * hop_size + window_size)]

    # Loop over each window of predictions
    for window_start in range(0, num_windows * hop_size, hop_size):
        window_end = window_start + window_size
        for i, timestep in enumerate(range(window_start, window_end)):
            for j in range(num_params):
                merged_predictions_list[timestep][j].append(predictions[int(window_start/hop_size)][i][j])

    # Determine mode for each timestep
    merged_predictions = np.zeros((len(merged_predictions_list), num_params))
    for i in range(len(merged_predictions_list)):
        for j in range(num_params):
            mode_val = mode(merged_predictions_list[i][j])[0]
            if np.isscalar(mode_val):
                merged_predictions[i][j] = mode_val
            else:
                merged_predictions[i][j] = mode_val[0]
    return merged_predictions

def merge_windows(predictions, window_size, hop_size):
    num_windows, win_size, num_params = predictions.shape
    assert win_size == window_size, "Provided window size does not match the predictions shape."

    # Define the size of the merged array
    merged_length = (num_windows-1) * hop_size + window_size
    merged_predictions = np.zeros((merged_length, num_params))

    # Create an overlap counter
    overlap_counter = np.zeros((merged_length, num_params))

    # Accumulate predictions and overlap count
    for window_start in range(0, num_windows * hop_size, hop_size):
        window_end = window_start + window_size
        merged_predictions[window_start:window_end] += predictions[int(window_start/hop_size)]
        overlap_counter[window_start:window_end] += 1

    # Calculate mode: Since you likely have binary values, you can determine mode by checking if the sum is > 0.5 * overlap_counter
    merged_predictions = np.where(merged_predictions > 0.5 * overlap_counter, 1, 0)

    return merged_predictions

# Usage:
merged_predictions = merge_windows(thresholded_predictions, window_size, window_skip)
merged_real_tabs = merge_windows(Y, window_size, window_skip)
merged_x = []

for song in manager.songs:
    merged_x.append(song.audio_processor.audio_data.T)

# Convert list of arrays to a single concatenated numpy array
merged_X = np.concatenate(merged_x, axis=0)

# %%
# Reverse the dictionary

mapping = {0: -1}
for idx, num in enumerate(range(29, 128)):
    mapping[num] = idx


reverse_dict = {v: k for k, v in mapping.items()}

def one_hot_to_encoding(one_hot_prediction, reverse_dict):
    hit_indices = np.argwhere(one_hot_prediction > 0)
    # Create an array with -1 for no hit
    encoding = np.full((one_hot_prediction.shape[0], 4), -1)
    
    # For each time step, fill in the hit values (up to 4)
    for t in range(one_hot_prediction.shape[0]):
        hits = hit_indices[hit_indices[:,0] == t]
        for i in range(len(hits)):
            hits[i, 1] = reverse_dict[hits[i, 1]]
        encoding[t,:len(hits)] = hits[:,1] # Use the dictionary to map to original encoding values
    
    return encoding

# Transform prediction
Y_pred_encoding = one_hot_to_encoding(merged_predictions, reverse_dict)
Y_pred_encoding = np.where(Y_pred_encoding == -1, 0, Y_pred_encoding)


Y_real = one_hot_to_encoding(merged_real_tabs, reverse_dict)
Y_real = np.where(Y_real == -1, 0, Y_real)

# %%
import matplotlib.pyplot as plt
import librosa
# Assuming the spectrogram is stored in a variable called "spectrogram"
# And the one-hot predictions are stored in a variable called "predictions"

fig, ax = plt.subplots(3, 1, sharex=True, figsize=(10, 10))

# Plotting the spectrogram
ax[0].imshow(merged_X.T, aspect='auto', cmap='jet', origin='lower')
ax[0].set_title('Spectrogram')

# Plotting the predicted drumhits
data = Y_pred_encoding  # Dummy data
for i in range(4):
    # Find where data is not 0
    hits = data[:, i] != 0
    
    ax[1].plot(np.arange(len(data))[hits], data[hits, i], marker='o', linestyle='', markersize=2, color='orange', label=f'Drum hit {i+1}')
plt.xlabel('Time steps')
plt.ylabel('Hit value')
ax[1].set_title('Predicted drumhits')

# Plotting the real drumhits
data = Y_real  # Dummy data
for i in range(4):
    # Find where data is not 0
    hits = data[:, i] != 0
    
    ax[2].plot(np.arange(len(data))[hits], data[hits, i], marker='o', linestyle='', markersize=2, color='red', label=f'Drum hit {i+1}')

plt.xlabel('Time steps')
plt.ylabel('Hit value')
ax[2].set_title('Real drumhits')

plt.tight_layout()
plt.show()

#S = librosa.feature.inverse.mel_to_stft(merged_X.T)
#y = librosa.griffinlim(S)

# %%
import IPython.display as ipd
from pydub import AudioSegment
from pydub.playback import play
from IPython.display import Audio

#audio_segment = AudioSegment(
#    y.tobytes(),
#    frame_rate=22050,
#    sample_width=y.dtype.itemsize,
#    channels=1  # For mono audio, use 2 for stereo
#)
#Audio(data=y, rate=22050)
#sr = 22050 # sample rate
#ipd.Audio(y, rate=sr, autoplay=True) # load a NumPy array
# Out:
# C:\Users\Daniel\PycharmProjects\auto-tabber\local_interpreter\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
 import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 8))
# Assuming `data` is your 2D array of shape (time_steps, 4)
data = merged_real_tabs.T  # Dummy data

colors = ['blue', 'orange', 'green', 'red']

for i in range(4):
    # Find where data is not 0
    hits = data[:, i] != 0
    
    ax.plot(np.arange(len(data))[hits], data[hits, i], marker='o', linestyle='', markersize=2, color='orange', label=f'Drum hit {i+1}')

plt.xlabel('Time steps')
plt.ylabel('Hit value')
plt.tight_layout()
plt.show()
